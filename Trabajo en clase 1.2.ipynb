# %%
class Muebles:

        def __init__(self, id, nombre, dimenciones, color, propiedad, material, ubicacion):
          self.__id = id
          self._
          _nombre = nombre
          self.__dimenciones = dimenciones
          self.__color = color
          self.__propiedad = propiedad
          self.__material = material
          self.__ubicacion = ubicacion

      # Mostrar  atributo

       # Id

        def getId(self):
          return self.__id

      # Nombre

        def getNombre(self):
          return self.__nombre

     # Dimenciones

        def getDimenciones(self):
          return self.__dimenciones

    # Color

        def getColor(self):
          return self.__color

    # Propiedad

        def getPropiedad(self):
          return self.__propiedad

    # Material

        def getMaterial(self):
          return self.__material

  # Ubicacion

        def getUbicacion(self):
          return self.__ubicacion

 # Metodos de modificacion

      # Id
        def setId(self, id):
          if isinstance(id, int) and id > 0:
            self.__id = id
          else:
            print("El id debe ser un numero entero")


       # Nombre

        def setNombre(self, nombre):
          if isinstance(nombre, str):
            self.__nombre = nombre
          else:
              print("El nombre debe ser una cadena de caracteres")


        # Dimeciones

          def setDimenciones(self, dimenciones):
            if isinstance(dimenciones, int) and dimenciones > 0:
              self.__dimenciones = dimenciones
            else:
              print("Las dimenciones deben ser una cadena de caracteres")

        # Color

          def setColor(self, color):
            if isinstance(color, str):
              self.__color = color
            else:
              print("El color debe ser una cadena de caracteres")

       # Propiedad

          def setPropiedad(self, propiedad):
            if isinstance(propiedad, str):
              self.__propiedad = propiedad
            else:
              print("La propiedad debe ser una cadena de caracteres")

        # Material

          def setMaterial(self, material):
            if isinstance(material, str):
              self.__material = material
            else:
              print("El material debe ser una cadena de caracteres")

        # Ubicacion

          def setUbicacion(self, ubicacion):
            if isinstance(ubicacion, str):
              self.__ubicacion = ubicacion
            else:
              print("La ubicacion debe ser una cadena de caracteres")

        # Mostrar

          def nostrar_inf(self):
            print(f"Id: {self.__id}, Nombre: {self.__nombre}, Dimencines: {self.__dimenciones}, Color: {self.__color}, Propiedad: {self.__propiedad}, Material: {self.__material}, Ubicacion: {self.__ubicacion}")

          def main():
            Mueble1 = Muebles(001, "Silla Ergonómica Ejecutiva", 120, "Negro", "Giratoria y ajustable en altura", "Cuero sintético y base de acero", "Oficina principal")
            Mueble2 = Muebles(002, "Cama Matrimonial Moderna", 200, "Blanco", "Incluye cabecera acolchonada", "Madera y tela", "Habitación principal")
            Mueble3 = Muebles(003, "Mesa de Oficina de Vidrio", 100, "Marrón", "Capacidad para 6 personas", "Vidrio y madera", "Oficina secundaria")

            # Informacion
            Mueble1.mostrar_inf()
            Mueble2.mostrar_inf()
            Mueble3.mostrar_inf()

            # Actualizar Id

            print(f"id acual: {Mueble1.get_id()}, {Mueble2.get_id()}, {Mueble3.get_id()}")

            Mueble1.set_id(2)
            Mueble2.set_id(3)
            Mueble3.set_id(4)

            print("Actualizar id Muebles 1")
            print("Actualizar id Muebles 2")
            print("Actualizar id Muebles 3")

            # Actualizar Nombre

            print(f"nombre actual: {Mueble1.get_nombre()}, {Mueble2.get_nombre()}, {Mueble3.get_nombre()}")

            Mueble1.set_nombre("Silla Ergonómica Ejecutiva")
            Mueble2.set_nombre("Cama Matrimonial Moderna")
            Mueble3.set_nombre("Mesa de Oficina de Vidrio")

            print("Actualizar nombre Muebles 1")
            print("Actualizar nombre Muebles 2")
            print("Actualizar nombre Muebles 3")

          # Actualizar Dimenciones

            print(f"dimencion actual: {Mueble1.get_dimencione()}, {Mueble2.get_dimenciones()}, {Mueble3.get_dimenciones()}")
# Out:
#   File "<tokenize>", line 52
#     def setId(self, id):
#     ^
# IndentationError: unindent does not match any outer indentation level
