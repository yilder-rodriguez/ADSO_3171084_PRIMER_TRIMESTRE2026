# %%
class Aprendiz:
  def __init__(self, id, nombre, edad, programa, trimestre, ambienete):
     self.__id = id
     self.__nombre = nombre
     self.__edad = edad
     self.__programa = programa
     self.__trimestre = trimestre
     self.__ambiente = ambienete

     #metodos

     def set_id(self, id):
      return self.__id

     def get_nombre(self):
      return self.__nombre

     def get_apellido(self):
      return self.__apellido

     def get_edad(self):
      return self.__edad

     def get_programa(self):
      return self.__programa

     def get_trimestre(self):
      return self.__trimestre

     def get_ambiente(self):
      return self.__ambiente

     def set_edad(self, nueva_edad):
      if isinstance (nueva_edad, (int)) and nueva_edad > 14:
        self.__edad = nueva_edad
      else:
        print("La edad debe ser mayor o igual a 14")

     def set_trimestre(self, nuevo_trimestre):
      if isinstance (nuevo_trimestre, (str)) and nuevo_trimestre:
        self.__trimestre = nuevo_trimestre
      else:
        print("El trimestre debe ser mayor a 1 ")

     def set_ambiente(self, nuevo_ambiente):
      if isinstance (nuevo_ambiente, (str)) and nuevo_ambiente:
        self.__ambiente = nuevo_ambiente
      else:
        print("el ambiente no debe quedar copn espacios sen blanco")

    #mostrar

     def mostar_inf(self):
      print(f"Id: {self._id}, Nombre: {self.nombre}, Apellido: {self.apellido}, Edad: {self.edad}, Progarama: {self.programa}, Trimestre: {self.trimnestre}, Ambiente: {self.ambiente}");
      print("----------------")

     def main():
      Aprendiz1 = Aprendiz(1, "Alejandra", "Carvajal", 17, "ingeneria civil", 4, "palos")
      Aprendiz2 = Aprendiz(2, "Camila", "Ortega", 15, "Administros finaciera", 5, "Numeros")
      Aprendiz3 = Aprendiz(3, "Juan", "Perez", 18, "Moda textil", 7, "Hilos")

      #Informacion
      Aprendiz1.mostar_inf()
      Aprendiz2.mostar_inf()
      Aprendiz3.mostar_inf()

      #Actualizacion edad
      print("Edad actual: " Aprendiz1.get_edad(), aprendiz2.get_edad(), aprendiz3.get_edad())

      Aprendiz1.set_edad(17)
      Aprendiz2.set_edad(15)
      Aprendiz3.set_edad(18)

      print("Actualizacion edad aprendiz 1:")
      print("Actualizacion edad aprendiz 2:")
      print("Actualizacion edad aprendiz 3:")

      #Actualizacion trimestre
      print("Trimestre actual: " Aprendiz1.get_trimestre(), aprendiz2.get, aprendiz3.get_trimestre())

      Aprendiz1.set_trimestre(4)
      Aprendiz2.set_trimestre(5)
      Aprendiz3.set_trimestre(7)

      print("Actualizacion trimestre aprendiz 1:")
      print("Actualizacion trimestre aprendiz 2:")
      print("Actualizacion trimestre aprendiz 3:")

      #Actualizacion ambiente
      print("Ambiente actual: " Aprendiz1.get_ambiente(), aprendiz(), Aprendiz2(), Aprendiz3())

      Aprendiz1.set_ambiente("palos")
      Aprendiz2.set_ambiente("Numeros")
      Aprendiz3.set_ambiente("Hilos")

      print("Actualizacion ambiente aprendiz 1:")
      print("Actualizacion ambiente aprendiz 2:")
      print("Actualizacion ambiente aprendiz 3:")

  if __name__ == "__main__":
        main()
# Out:
#   File "/tmp/ipython-input-4074901240.py", line 68
#     print("Edad actual: " Aprendiz1.get_edad(), aprendiz2.get_edad(), aprendiz3.get_edad())
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
